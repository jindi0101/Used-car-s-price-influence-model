# %%
from bs4 import BeautifulSoup
import urllib
import requests

import pandas as pd
def extract(): 
    url='https://www.hermes.com/us/en/product/picotin-lock-18-bag-H056289CK3Q/'
    website=requests.get(url)
    soup=BeautifulSoup(website.content,'html.parser')
    tag=soup('span')
    for t in tag:
        print(t)#.get('class',None))
extract()
# Out:
# <span _ngcontent-sc464="" class="sr-only">Homepage Hermès Paris</span>
# <span _ngcontent-sc463="" class="ng-tns-c463-2">Menu</span>
# <span _ngcontent-sc463="" class="ng-tns-c463-2">Account</span>
# <span _ngcontent-sc463="" class="ng-tns-c463-2">Cart</span>
# <span _ngcontent-sc463="" class="sr-only" id="accessibility-header-cart-count">empty</span>
# <span>View</span>
# <span class="ng-star-inserted">Worn</span>
# <span _ngcontent-sc474="" class="ng-tns-c474-5"></span>
# <span _ngcontent-sc474="" class="ng-tns-c474-5 ng-star-inserted"> , <!-- -->zoom image</span>
# <span>View</span>
# <span class="ng-star-inserted">front</span>
# <span>View</span>
# <span class="ng-star-inserted">side</span>
# <span>View</span>
# <span class="ng-star-inserted">above</span>
# <span>View</span>
# <span class="ng-star-inserted">below</span>
# <span>View</span>
# <span class="ng-star-inserted">Worn</span>
# <span>View</span>
# <span class="ng-star-inserted">front</span>
# ...
